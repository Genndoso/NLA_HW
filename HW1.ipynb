# %% [markdown]
# # Problem Set 1 (96 points)

# %% [markdown]
# # Pavlov Maksimilian

# %% [markdown]
# ## Important information
# 1. We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2. Please submit the single Jupyter Notebook file, where only Python and Markdown/$\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!

# %% [markdown]
# # Problem 1 (Theoretical tasks)  (36 pts)
#
# _1._
# - (1 pts) What are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$ for any vector $x$
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.
#
# _2._
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. _Hint:_ SVD will help you.
# - (5 pts) Show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
# - (5 pts) Prove that if $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $\det(\exp(A)) = \exp(\mathrm{trace}(A))$.
#
# _Hint:_ $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$, moreover $\exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$ where $D = \mathrm{diag}(d_1, d_2, ..., d_n)$ - diagonal matrix with diagonal values $d_1, d_2, ..., d_n$
#
#
# - (5 pts) Prove that $\| A B \|_2 \le \| A \|_2 \| B \|_F$.
#
# _3._
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$
# - (3 pts) Compute  pseudoinverse of the matrix analytically
#
# $$
# A = \begin{bmatrix}
# 2\\
# 3\\
# \vdots\\
# \sqrt{5n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$

# %% [markdown]
# # Solution of problem 1

# %% [markdown]
# ### 1.1.

# %% [markdown]
# <center>  $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$

# %% [markdown]
# Let's rewrite inequalities

# %% [markdown]
# <center> $   \|x\|_{\infty}  \geq C_1 \|x\|_{1} $ \\
# $  \|x\|_{\infty} \leq   C_2 \| x\|_{1}$

# %% [markdown]
# Divide on  $\|x\|_{1}$ considering that x not equal to zero. \\\

# %% [markdown]
# <center> $ C_1 \leq \frac{max|x_i|}{\sum_{i=1}|x_i|} $ </center>
# <center> $ C_2 \geq \frac{max|x_i|}{ \sum_{i=1}|x_i|} $ <center>

# %% [markdown]
# The case when every of this constant is minimal when vector x includes one non-zero element. Therefore, $ max|x_i| = \sum_{i=1}|x_i| $. In other cases when x will contain more than one non-zero element there will be $ max|x_i| \leq \sum_{i=1}|x_i| $

# %% [markdown]
# Thus, $C_2 \geq 1, C_1 \leq 0 $

# %% [markdown]
# ### 1.2.

# %% [markdown]
# <center> $\| U A \|_F = \| A U \|_F = \| A \|_F$.

# %% [markdown]
# Unitary matrix preserve the norm. I will square Frobenius norm. Also, Frobenious norm is equal to square root trace of dot product of transpose and initial matrix

# %% [markdown]
# <center> $\|  A \|_F = \sqrt[2]{Tr[(A^T*A)]}\ $.

# %% [markdown]
# <center> $\| U A \|^2_F = Tr[(U A)^T U A] = Tr[A^T U^T U A] $

# %% [markdown]
# Important property of unitary matrix is $ U^T*U=1 $. Thus, $ Tr[A^T U^T UA] =Tr[A^T 1 A] = \| A \|^2_F  $

# %% [markdown]
# <center> $\| A U \|^2_F = Tr[(A U)^T A U] = Tr[U^T A^T A U] = Tr[U^T A^T A U] $

# %% [markdown]
# Use property of  traces $Tr(AB)=Tr(BA)$
# $=Tr[A U  U^TA^T ] = Tr[AA^T] = Tr[A^T A]=\| A \|^2_F $

# %% [markdown]
# ### 1.3.

# %% [markdown]
# <center> $\| U A \|_2 = \| A U \|_2 =\| A \|_2  $

# %% [markdown]
# <center> $\|  A \|_2 = \sqrt[2]{\lambda_m ( (A)^* A) } = \sigma_{max} (A)$

# %% [markdown]
# Let's square L2 norm

# %% [markdown]
# Lets implement SVD decomposition to A matrix $A=OEV^* $.

# %% [markdown]
# By multiplying A on U unitary matrix from left and from right, singular we will get a SVD decompostion of UA and AU

# %% [markdown]
# $ OE(V^*U) =UOEV^*  $ \\
# $ \sigma_{max}(A) = \sigma_{max}(AU) = \sigma_{max}(UA) $
# Then

# %% [markdown]
# <center> $\| U A \|_2 =  \| AU \|_2 =\|  A \|_2 $ \\

# %% [markdown]
# ### 2.1.

# %% [markdown]
# <center> $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$

# %% [markdown]
# Lets implement SVD decomposition to the $A$ matrix \\\
# $A=UEV^*$ where $U,V$ is unitary matrices, E is a diagonal matrix. Also, I will divide to l2 norm

# %% [markdown]
# $\frac{\| UEV^* \|_F}{ \| UEV^* \|_2}\le \sqrt{\mathrm{rank}(UEV^*)}$

# %% [markdown]
# Implement invariance of rank under unitary transforms

# %% [markdown]
# $$\frac{\| E \|_F}{ \| E \|_2}\le \sqrt{\mathrm{rank}(E)}$$

# %% [markdown]
#  $$\frac{\sqrt{TrE^2}}{\sqrt{\sigma_mE^2}}\le \sqrt{\mathrm{rank}(E)}$$

# %% [markdown]
# $$\frac{TrE^2}{\sigma_mE^2}\le \mathrm{rank}(E)$$

# %% [markdown]
# $$\frac{\sigma^2_1+\sigma^2_2+...+\sigma^2_n}{\sigma^2_1}\le \mathrm{rank}(E)$$

# %% [markdown]
# $$1+\frac{\sigma^2_2}{\sigma^2_1}+...+\frac{\sigma^2_n}{\sigma^2_1} \le \mathrm{rank}(E)$$

# %% [markdown]
# $$\frac{\sigma^2_2}{\sigma^2_1};...;\frac{\sigma^2_n}{\sigma^2_1} \le 1 $$

# %% [markdown]
# $$ 1+\frac{\sigma^2_2}{\sigma^2_1}+...+\frac{\sigma^2_n}{\sigma^2_1} \le n$$, where $n$-amount of elements on the diagonal of the matrix what is equal to the rank of the matrix

# %% [markdown]
# $$ 1+\frac{\sigma^2_2}{\sigma^2_1}+...+\frac{\sigma^2_n}{\sigma^2_1} \le \mathrm{rank}(E)$$

# %% [markdown]
# ### 2.2.

# %% [markdown]
# for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$.

# %% [markdown]
# One case which prove that this inequaility is not strict, it is when A matrix is decomposed by SVD ($A=U\sum V^*) and $ \sum $ diagonal matrix consist of equal non-zero singular values

# %% [markdown]
# $$\sigma_1=\sigma_2=...=\sigma_n $$

# %% [markdown]
# $$\| A \|_F =\sqrt{\sum_{i=1}\sigma_i} =\sigma \sqrt{k} = \sqrt{\mathrm{rank}(A)} \| A \|_2 $$

# %% [markdown]
# ### 2.3.

# %% [markdown]
# $$\det(\exp(A)) = \exp(\mathrm{trace}) $$. If $A \in \mathbb{R}^{n \times n}$ is dioganazible matrix then $A=S^{-1}DS$. $D$ is diganal matrix

# %% [markdown]
# $$det(exp(S^{-1}DS))=exp(tr(S^{-1}DS))$$

# %% [markdown]
# $$det(S^{-1}exp(D)S))=exp(tr(S^{-1}exp(D)S)$$

# %% [markdown]
# $$det(S^{-1})det(exp(D))det(S)=exp(tr(S^{-1}Sexp(D))$$

# %% [markdown]
# $$det(S^{-1})det(exp(D))det(S)=exp(tr(S^{-1}Sexp(D))$$

# %% [markdown]
# $$det(S^{-1})=\frac{1}{det(S)}$$

# %% [markdown]
# $$\frac{1}{det(S)}det(S)det(exp(D))=exp(trD)$$

# %% [markdown]
# $$det(exp(D))=exp(trD)$$

# %% [markdown]
# $$e^{d_1}\cdot e^{d_2}\cdot...\cdot e^{d_n} =e^{d_1+d_2+...+d_n} $$

# %% [markdown]
# ### 2.4.

# %% [markdown]
# $$\| A B \|_2 \le \| A \|_2 \| B \|_F$$

# %% [markdown]
# Lets make SVD decomposition to B: $B=EUV^*$

# %% [markdown]
# $$\| B \|^2_F =Tr(B^*B)=Tr((UEV^*)^*UEV)=Tr(VEU^*UEV^*)=Tr(VEEV^*)= Tr(EE) \lambda_{max}|E^*E|=\| B \|_2 $$
# $$\| B \|_2=\sigma_{max}  $$

# %% [markdown]
# $$\| B \|_2=\sigma_{max} \leq \sqrt{\sum_{i}\sigma^2_i} =\sqrt{Tr(EE)} = \| B \|_F$$

# %% [markdown]
# Using submultiplicative property

# %% [markdown]
# $$ \| AB \|_2 \leq \| A \|_2 \| B \|_2 \leq \| A \|_2 \| B \|_F $$

# %% [markdown]
# ### 3.1.

# %% [markdown]
# <center>  Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$

# %% [markdown]
#  $$ (UU^*)^+ =\lim_{\alpha\to +0}{(\alpha I+(UU^*)^*UU^*)^{-1} (U U^*)^*)}=[(UU^*)^*UU^*]^{-1}UU^*=[UU^*UU^*]^{-1}UU^*=[UU^*]^{-1}UU^*=U^{-*}U^{-1}UU^*=U^{-*}U^*=I_k$$
#  Firstly, I've got this answer. But, I missed the point that $UU^*$ is singular: $rank(I_k)=min(rank(U^*),rank(U))=rank(UU^*)$. Since $k<n$, $UU^*$ is singular.
#  $$UU^*=W\Sigma V^*$$
#  $$(W \Sigma V^*)^\dagger=V \Sigma W^*$$
#  Thus, $$ UI^{-1}_kU^*=UU^*$$
#  I

# %% [markdown]
# ### 3.2.

# %% [markdown]
# $$A = \begin{bmatrix}
# 2\\
# 3\\
# \vdots\\
# \sqrt{5n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$

# %% [markdown]
# # Problem 2 (Matrix calculus) (15 pts)
#
# _1._ (11 pts) Consider the following function
#
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
# - (7 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion
#
# _2._ (4 pts) Derive analytical expression for the gradient and hessian of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %%
# Your solution is here

# %% [markdown]
# $$ \nabla F(U, V) = \nabla \frac{1}{2}\|X - UDV\|_F^2$$
# $$ d \|X \|_F^2 =  2 (X, dX) $$
#
# I will use Guru approach
#
# 1.1. $$ d_V F(U, V) = ((X - UDV), d(X - UDV)) = -((X - UDV), UD d(V)) = -(D^TU^T (X - UDV), dV) $$
#
# $$ \nabla_V F(U, V) = -(X - UDV)(UD)^T $$
#
# 1.2
#
# $$ d_U F(U, V) = ((X - UDV), d(X - UDV)) = -((X - UDV)(DV)^T, dU) $$
#
# $$\nabla_U F(U, V) = -(X - UV)(DV)^T $$

# %% [markdown]
# 1.3

# %% [markdown]
# $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$
#
#
# $$-(X - UDV)(UD)^T$$
# Total O-complexity   $$O(UD)->O(UD(V))->X-UDV $$
# $$ O(DV)=nk $$
# $$ O(UD) = nk $$
# $$O((UD)V)= $O(kn^2)$$
# $$ O(X-UDV) = $O(n^2)$$
#
# Total $$(X-UDV)(UD)^T = O(kn^2)$$

# %%
import jax
import jax.numpy as jnp
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
def norm(X, U, V):
    frob = jnp.linalg.norm(X - U @ V)
    return 0.5 * frob * frob

# %%
# complexity of row dimension

n_list = list(np.arange(100,2000, 100))

analytic_grad = np.zeros(len(n_list), dtype=np.float64)
jgradient = np.zeros(len(n_list), dtype=np.float64)


for j,n in enumerate(n_list):

  k = 100
  
  X = jax.random.normal(jax.random.PRNGKey(1), (n, n))
  U = jax.random.normal(jax.random.PRNGKey(3), (n, k))
  V = jax.random.normal(jax.random.PRNGKey(5), (k, n))

  jax_gradient = jax.grad(norm, argnums=1, has_aux=False)
  
  # time of analitical gradient
  time1 = np.zeros(50,dtype=np.float64)
  time2 = np.zeros(50,dtype=np.float64)
  for i in range(50):

    start = time.time()
    analytical_time = (U @ V -  X) @ V.T
    end = time.time()
    time1[i] = end-start
    


    start = time.time()
    jax_time=  jax_gradient(X, U, V).block_until_ready()
    end = time.time()
    time2[i] = end-start

  jgradient[j] = time2.mean()
  analytic_grad[j] = time1.mean()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
plt.plot(n_list, analytic_grad, color="black", label="Analytical_gradient")
plt.plot(n_list, jgradient, color="red", label="Jax_grad")

plt.title('Change n, grad by U')
plt.ylabel("time")
plt.xlabel("n")
plt.legend(loc="upper center", ncol=3)

# %%
# complexity of column dimension

n_list = list(np.arange(100,1200, 100))

analytic_grad = np.zeros(len(n_list), dtype=np.float64)
jgradient = np.zeros(len(n_list), dtype=np.float64)


for j,k in enumerate(n_list):

  n = 1500
  
  X = jax.random.normal(jax.random.PRNGKey(1), (n, n))
  U = jax.random.normal(jax.random.PRNGKey(3), (n, k))
  V = jax.random.normal(jax.random.PRNGKey(5), (k, n))

  jax_gradient = jax.grad(norm, argnums=1, has_aux=False)
  
  # time of analitical gradient
  time1 = np.zeros(50,dtype=np.float64)
  time2 = np.zeros(50,dtype=np.float64)
  for i in range(50):

    start = time.time()
    analytical_time = (U @ V -  X) @ V.T
    end = time.time()
    time1[i] = end-start
    


    start = time.time()
    jax_time=  jax_gradient(X, U, V).block_until_ready()
    end = time.time()
    time2[i] = end-start

  jgradient[j] = time2.mean()
  analytic_grad[j] = time1.mean()

# %%
plt.plot(n_list, analytic_grad, color="black", label="Analytical_gradient")
plt.plot(n_list, jgradient, color="red", label="Jax_grad")

plt.title('Change k, grad by U')
plt.ylabel("time")
plt.xlabel("k")
plt.legend(loc="upper center", ncol=3)

# %% [markdown]
# Actually, analytical gradient is faster than jax.

# %% [markdown]
# 2
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
#
# $$ \frac{d R(x)}{dx} = \frac{\frac{d (Ax, x)}{dx}(x, x) - \frac{d (x, x)}{dx} (Ax, x)}{(x, x)^2} $$
#
# $$ A^T=A $$
#
# 1) $$\frac{d (Ax, x)}{dx_k} = (Ax,dx)+(Adx,x)=(Ax,dx)+(A^Tx,dx)=(A+A^T)x$$
#
#
#
# $$ \frac{d (Ax, x)}{dx} = (A + A^T) x = 2Ax $$
#
# 2) $$ \frac{d (x, x)}{dx_k} = (x,dx)+(dx,x)=(x,dx)+(x,dx) =2(x,dx)$$
# $$ \frac{d (x, x)}{dx} =  2x$$
#
# $$ \frac{d R(x)}{dx} = \frac{ 2Ax(x, x) - 2x (Ax, x)}{(x, x)^2} $$

# %% [markdown]
# # Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)
#
# In this problem we consider the neural network that performs classification of the dataset of images.
# Any neural network can be considered as composition of simple linear and non-linear functions.
# For example, a neural network with 3 layers can be represented as
#
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy.
# Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed.
# The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# #### Zero step: install PyTorch
#
# - Follow the steps in [official instructions](https://pytorch.org/get-started/locally/)

# %%
#conda config --remove channels http://ta-lib.org

# %% [markdown]
# #### First step: download CIFAR10 dataset

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %% [markdown]
# #### Check what images are we going to classify

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# plane   car   dog   cat plane  frog  frog truck

# %% [markdown]
# ### Second step: neural network architecture
#
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them.
# To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch.
# More details about neural networks you will study in the *Deep learning* course in one of the upcoming term

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, middle_features, activation=nn.ReLU()):
        super().__init__()
        self.layer1 = nn.Linear(in_features, middle_features)
        self.layer2 = nn.Linear(middle_features, in_features)
        self.activation = activation
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.activation(out)
        out = self.layer2(out)
        out = out + x
        out = self.activation(out)
        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.res1 = ResidualBlock(1000,1000)
        self.res2 = ResidualBlock(1000,1000)
        self.fc2 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Implement functions for training and testing after every sweep over all dataset entries

# %%
def train(model, train_loader, optimizer, epoch):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.train()
    model.to(device)
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    device = "cuda" if torch.cuda.is_available() else "cpu"
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# ### Set parameters for training and print intermediate loss values

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Third step: run training with the [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document) optimization method
#
# If your laptop is not very fast, you will wait some time till training is finished.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.290601
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.816379
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.583613
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.703405
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.520217
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.399136
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.502112
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.528662
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.418871
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.479092
#
# Test set: Average loss: 1.4682, Accuracy: 4767/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.216286
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.558427
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.307773
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.538436
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.397519
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.373903
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.293560
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.387498
# ...

# %% [markdown]
# Now we have somehow trained neural network and we are ready to perform compression of the weigths in the fully-connected layers.

# %% [markdown]
# - (3 pts) Compute SVD of the matrix $1000 \times 1000$, which corresponds to a weight matrix $A$ in each layer of residual blocks. To find more information about accessing this matrix please refer to [PyTorch manual](https://pytorch.org/docs/stable/index.html).
# Plot decaying of the singular values like it was shown in the lecture. What conclusion can you make?
# - (17 pts) Create a new model, which is an analogue to the class ```Net```, but with some significant distinctions.
# It takes as input parameters the instance of the class ```Net``` and compression rank $r > 0$.
# After that, this model has to compress all matrices $A$ in fully-connected layers with SVD using first $r$ singular vectors and singular values.
# Pay attention to efficient storing of compress representation of the layers.
# Also ```forward``` method of your new residual block has to be implemented in a way to use compressed representation of the fully-connected layers (inside it) in the most efficient way. In all other aspects it has to reproduce ```forward``` method in the original non-compressed model (number of layers, activations, loss function etc).
# - (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank $r$.
# Also plot dependence of time to compute inference on the compression rank $r$.
# Explain obtained results.
# To measure time, use [%timeit](https://docs.python.org/3.6/library/timeit.html) with necessary parameters (examples of using this command see in lectures)
#
# - (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called **fine-tuning**. We ask you make this fine-tuning of your compressed model during from 1 to 5 epochs and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results.
#
#     **Hint 1**. Please, check that during fine-tuning, factors are updated. If they are not updated according to some reason, please check that their parameter ```requires_grad``` is setted to ```True```.
#
#     **Hint 2**. You can use class ```torch.nn.Parameter``` to convert factors to parameters of the network

# %%
import numpy as np

# %% [markdown]
# 3.1.

# %%
model.res1.layer1.weight.detach().numpy()
# Out:
# array([[ 0.01794693, -0.01939379, -0.02660807, ..., -0.00961715,
#         -0.00896188,  0.03610368],
#        [-0.06008394, -0.01936709,  0.00670082, ..., -0.03390496,
#         -0.00294348, -0.05430964],
#        [ 0.0110811 ,  0.02489535,  0.02427481, ..., -0.0226204 ,
#         -0.029955  , -0.01033202],
#        ...,
#        [ 0.00996617,  0.00888857,  0.01530403, ..., -0.01215989,
#          0.0035512 , -0.01066713],
#        [ 0.00060703, -0.01325492,  0.02480864, ..., -0.00553975,
#          0.02197033, -0.02350004],
#        [-0.07325452,  0.02113752,  0.02246413, ..., -0.05901231,
#          0.05590594, -0.08183981]], dtype=float32)

# %%
model._modules.values()
# Out:
# odict_values([Linear(in_features=3072, out_features=1000, bias=True), ResidualBlock(
#   (layer1): Linear(in_features=1000, out_features=1000, bias=True)
#   (layer2): Linear(in_features=1000, out_features=1000, bias=True)
#   (activation): ReLU()
# ), ResidualBlock(
#   (layer1): Linear(in_features=1000, out_features=1000, bias=True)
#   (layer2): Linear(in_features=1000, out_features=1000, bias=True)
#   (activation): ReLU()
# ), Linear(in_features=1000, out_features=10, bias=True), ReLU()])

# %%
# Your solution is here
#3.1.
res1_layer1 = model.res1.layer1.weight.detach().numpy()
res1_layer2 = model.res1.layer2.weight.detach().numpy()
res2_layer1 = model.res2.layer1.weight.detach().numpy()
res2_layer2 = model.res2.layer2.weight.detach().numpy()

u, s1, v = np.linalg.svd(res1_layer1)
u, s2, v = np.linalg.svd(res1_layer2)
u, s3, v = np.linalg.svd(res2_layer1)
u, s4, v = np.linalg.svd(res2_layer2)

plt.semilogy(s1[:500]/s1[0], 'x',label='res1_layer1')
plt.semilogy(s2[:500]/s2[0], 'x',label='res1_layer2')
plt.semilogy(s3[:500]/s3[0], 'x',label='res2_layer1')
plt.semilogy(s4[:500]/s4[0], 'x',label='res2_layer2')
plt.ylabel(r"$\sigma_i / \sigma_0$", fontsize=24)
plt.xlabel(r"Singular value index, $i$", fontsize=24)
plt.grid(True)
plt.legend()
plt.xticks(fontsize=26)
plt.yticks(fontsize=26)
# Out:
# (array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# It is clearly seen from the graph that the most effective approximation is low-rank, because relative singular values are rapidly dereasing in the first 100 singular values.

# %% [markdown]
# 3.2.

# %%
   
class my_ResidualBlock(nn.Module):
    def __init__(self, residual_block, rank, activation=nn.ReLU()):
        super().__init__()
        u1, s1, v1 =np.linalg.svd(residual_block.layer1.weight.data)

        self.u1 = torch.tensor(u1[:, :rank]) 
        self.s1 = torch.tensor(np.diag(s1[:rank])) 
        self.v1 = torch.tensor(v1[:rank,:]) 
    
        self.bias1 = residual_block.layer1.bias.data.clone()
                
        self.u1s1 = nn.Parameter(self.u1 @ self.s1, requires_grad=True)
       
        self.v1 = nn.Parameter(self.v1, requires_grad=True)

  
             
        u2, s2, v2 = np.linalg.svd(residual_block.layer2.weight.data)
        self.u2 = torch.tensor(u2[:, :rank]) 
        self.s2 = torch.tensor(np.diag(s2[:rank])) 
        self.v2 = torch.tensor(v2[:rank,:]) 

        
        self.bias2 = residual_block.layer2.bias.data.clone()
        
        self.u2s2 = nn.Parameter(self.u2 @ self.s2, requires_grad=True) 
       
        self.v2 = nn.Parameter(self.v2, requires_grad=True)
        
        self.activation = activation

    def forward(self, x):
        out = x @ (self.u1s1 @ self.v1).T+self.bias1
        out = self.activation(out)
        out = out @ (self.u2s2 @ self.v2).T+self.bias2
        out = out + x
        out = self.activation(out)
        return out



class compressed_Net(nn.Module):
   
    def __init__(self, model, rank):
        super().__init__()
        self.rank = rank
        
        self.ReLU = model.ReLU
        self.model2 = model

       
        self.fc1 = model.fc1
        self.fc2 = model.fc2

        self.res1 =  my_ResidualBlock(model.res1, rank)
        self.res2 =  my_ResidualBlock(model.res2, rank)
         
        self.ReLU = nn.ReLU()
      #  self.W11 = model.res1.layer1.weight.detach().numpy()
      #  self.W12 = model.res1.layer2.weight.detach().numpy()
      #  self.W21 = model.res2.layer1.weight.detach().numpy()
      #  self.W22 = model.res2.layer2.weight.detach().numpy()

      #  self.u1, self.s1, self.v1 = np.linalg.svd(self.W11)
      #  self.u2, self.s2, self.v2 = np.linalg.svd(self.W12)
      #  self.u3, self.s3, self.v3 = np.linalg.svd(self.W21)
      #  self.u4, self.s4, self.v4 = np.linalg.svd(self.W22)

        # self.B11= model.res1.layer1.bias.detach().numpy()
         # self.B12= model.res1.layer2.bias.detach().numpy()
         # self.B21= model.res2.layer1.bias.detach().numpy()
         # self.B22= model.res2.layer2.bias.detach().numpy()


         
      #  self.u1 = torch.tensor(u1[:, :rank]) 
      #  self.s1 = torch.tensor(np.diag(s1[:rank])) 
      #  self.v1 = torch.tensor(v1[:rank,:]) 

      #  self.u2 = torch.tensor(u2[:, :rank]) 
      #  self.s2 = torch.tensor(np.diag(s2[:rank])) 
      #  self.v2 = torch.tensor(v2[:rank,:]) 

       # self.u3 = torch.tensor(u3[:, :rank]) 
       # self.s3 = torch.tensor(np.diag(s3[:rank])) 
      #  self.v3 = torch.tensor(v3[:rank,:]) 

       # self.u4 = torch.tensor(u4[:, :rank]) 
       # self.s4 = torch.tensor(np.diag(s4[:rank])) 
     #   self.v4 = torch.tensor(v4[:rank,:]) 
#
          
       # self.res1.layer1.weight = torch.nn.Parameter(self.u1 @ self.s1 @ self.v1) 
      #  self.res1.layer2.weight = torch.nn.Parameter(self.u2 @ self.s2 @ self.v2) 
      #  self.res2.layer1.weight = torch.nn.Parameter(self.u3 @ self.s3 @ self.v3) 
      #  self.res2.layer2.weight = torch.nn.Parameter(self.u4 @ self.s4 @ self.v4) 
    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
model2 = compressed_Net(model, 1000)
test(model2,test_loader)
# Out:
# Test set: Average loss: 1.4960, Accuracy: 5297/10000 (53%)

# %%
model2 = compressed_Net(model, 100)
test(model2,test_loader)
# Out:
# Test set: Average loss: 1.4938, Accuracy: 5348/10000 (53%)

# %%
import timeit

# %%
def test1(model, test_loader):
    model.eval()
    test_loss = 0
    times = []
    correct = 0
    device = "cuda" if torch.cuda.is_available() else "cpu"
    with torch.no_grad():
        for data, target in test_loader:
            times.append(timeit.timeit(lambda: model(data), number=10))
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset), np.array(times).mean()

# %%
ranks = np.arange(0,1100,100,dtype=int).tolist()
ranks
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# %%
times = []
accuracy = np.zeros(len(ranks))
percent =  np.zeros(len(ranks))

percent_acc_standart = np.zeros(len(ranks))
for i,rank in enumerate(ranks):
  model2 = compressed_Net(model, int(rank))


  percent_acc_standart[i] = 54
  acc = test1(model2, test_loader)
  accuracy[i] =acc[1]
  percent[i] = acc[0]
  times.append(time)
# Out:
# Test set: Average loss: 4.8759, Accuracy: 4110/10000 (41%)
#
#
# Test set: Average loss: 1.4938, Accuracy: 5348/10000 (53%)
#
#
# Test set: Average loss: 1.4967, Accuracy: 5343/10000 (53%)
#
#
# Test set: Average loss: 1.4977, Accuracy: 5341/10000 (53%)
#
#
# Test set: Average loss: 1.4934, Accuracy: 5327/10000 (53%)
#
#
# Test set: Average loss: 1.4945, Accuracy: 5320/10000 (53%)
#
#
# Test set: Average loss: 1.4949, Accuracy: 5319/10000 (53%)
#
#
# Test set: Average loss: 1.4949, Accuracy: 5310/10000 (53%)
#
#
# Test set: Average loss: 1.4955, Accuracy: 5300/10000 (53%)
#
#
# Test set: Average loss: 1.4959, Accuracy: 5298/10000 (53%)
#
#
# Test set: Average loss: 1.4960, Accuracy: 5297/10000 (53%)

# %% [markdown]
# 3.3.

# %%
plt.plot(ranks,accuracy,label='time')

plt.ylabel(r"time", fontsize=14)
plt.xlabel(r"rank", fontsize=14)
plt.grid(True)
plt.legend()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6]),
#  <a list of 8 Text major ticklabel objects>)

# %%
for i in range(len(ranks)):

  percent_acc_standart[i]=53

# %%
plt.plot(ranks,percent,label='accuracy',color='r')
plt.plot(ranks,percent_acc_standart,label='accuracy of full rank matrix',color='b')
plt.ylabel(r"accuracy", fontsize=14)
plt.xlabel(r"rank", fontsize=14)
plt.grid(True)
plt.legend()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([40., 42., 44., 46., 48., 50., 52., 54., 56.]),
#  <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# After compressing we lost some information, but according to plots there is clearly seen that after compression to 200-rank matrix there is similar accuracy as in full rank matrix. Thus, we may save a lot of extra cumputations which is quite useful while working with high-dimensionality data

# %% [markdown]
# 3.4.

# %%
def train(model, train_loader, optimizer, epoch):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.train()
    model.to(device)
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
epochs = 5

# %%
model2 = compressed_Net(model, 250)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model2,  train_loader, optimizer, epoch)
    test(model2, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 0.528776
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 0.675152
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 0.694868
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 0.683975
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 0.613103
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 0.588151
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 0.878236
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 0.711055
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 0.638477
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 0.565264
#
# Test set: Average loss: 1.5638, Accuracy: 5475/10000 (55%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.417170
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 0.625160
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 0.482595
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 0.564389
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 0.530627
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 0.621563
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 0.564644
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 0.535687
# ...

# %% [markdown]
# Fine-tuning of comressed neural networks will serve more useful information and less noise. Also, mu suggestion is that compressed NN faster find patterns and less inclined to be overfitted.

# %% [markdown]
# #Fine

# %% [markdown]
# ## Problem 4. «Reducio!» (15 pts)

# %% [markdown]
# Hermione Granger is well versed in all magical disciplines. In particular, she is a great expert in Numerical Linear Algebra and JAX.
#
# She has invited Harry Potter to play the game.
#
# Hermione chooses a number $r \in [1, 95]$ and two matrices $W_1 \in \mathbb{R}^{r \times 100}$ and $W_2 \in \mathbb{R}^{100 \times r}$.
# Harry can tell her any 100-dimensional vector $x$, and Hermione gives Harry the result of
#
# $$ ||\sin(W_2 \cos(W_1 x))||^2_2,$$
#
# where trigonometric functions are applied element-wise. The result is the squared norm of a 100-dimensional vector.
#
# Not to lose, Harry should guess what number $r$ Hermione has chosen.
# Harry knows the python language, but he is an absolute layman in algebra. Please, help him to get at least 95% correct answers!
#
# <i> Hint 1: SVD might help you, but use it wisely! </i>
#
# <i> Hint 2: Suppose that a special magic allows you to compute gradients through automatic differentiation in JAX. You can also estimate gradients via finite differences, if you want it.</i>
#
# <i> Hint 3: You can estimate the matrix rank using simple heuristics.
#
# You should write code into the `harry_answers` function. Good luck!

# %%
import jax.numpy as jnp
import jax
import numpy as np
import random

class Game:
    def __init__(self, key):
        # key is a jax.random.PRNGKey
        self.key = key
        return
    def hermione_chooses_r_and_W(self):
        self.r = random.randint(1, 95)
        self.key, subkey = jax.random.split(self.key)
        self.W1 = jax.random.uniform(subkey, (self.r, 100), maxval=100., minval=0., dtype=jnp.float32)
        self.key, subkey = jax.random.split(self.key)
        self.W2 = jax.random.uniform(subkey, (100, self.r), maxval=100., minval=0., dtype=jnp.float32)
    def hermione_computes_function(self, x):
        return jnp.sum(jnp.square(jnp.sin(self.W2 @ jnp.cos(self.W1 @ x))))
    def harry_answers(self):
        # <your code here>
        # you shouldn't use self.r, self.W1, or self.W2
        # you can call `hermione_computes_function` multiple times
        x = jax.random.normal(self.key, (100,100))
        jacobi = jax.jacfwd(self.hermione_computes_function, argnums=0)
        u, s, v = np.linalg.svd(jacobi(x))
        error = 1
        r = (s>error).sum() 
        
      
        return r
    
    def play(self, n_rounds, verbose=True):
        # n_rounds: a number of rounds of the game
        # verbose: print or not the result of each round
        n_right_answers = 0
        for _ in range(n_rounds):
            self.hermione_chooses_r_and_W()
            r = self.harry_answers()
            if abs(r - self.r) == 0:
                if verbose:
                    print("Good job! The true answer is {}, Harry's answer is {}!".format(self.r, r))
                n_right_answers += 1
            else:
                if verbose:
                    print("Harry's answers is {}, but the true answer is {} :(".format(r, self.r))
        if float(n_right_answers) / n_rounds > 0.95:
            print('Well done: {}/{} right answers!'.format(n_right_answers, n_rounds))
        else:
            print('Only {}/{} right answers :( Work a little more and you will succeed!'.format(
                n_right_answers, n_rounds))

# %%
key = jax.random.PRNGKey(713)
game = Game(key)
game.play(n_rounds=100, verbose=True)
# Out:
# Good job! The true answer is 71, Harry's answer is 71!
# Good job! The true answer is 45, Harry's answer is 45!
# Good job! The true answer is 47, Harry's answer is 47!
# Good job! The true answer is 35, Harry's answer is 35!
# Good job! The true answer is 16, Harry's answer is 16!
# Good job! The true answer is 28, Harry's answer is 28!
# Good job! The true answer is 13, Harry's answer is 13!
# Good job! The true answer is 87, Harry's answer is 87!
# Good job! The true answer is 26, Harry's answer is 26!
# Good job! The true answer is 17, Harry's answer is 17!
# Good job! The true answer is 23, Harry's answer is 23!
# Good job! The true answer is 91, Harry's answer is 91!
# Good job! The true answer is 37, Harry's answer is 37!
# Good job! The true answer is 24, Harry's answer is 24!
# Good job! The true answer is 36, Harry's answer is 36!
# Good job! The true answer is 87, Harry's answer is 87!
# Good job! The true answer is 72, Harry's answer is 72!
# ...
